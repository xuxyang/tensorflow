# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'originated', 'term', 'anarchism', 'originated', 'as', 'term', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.125229
# Nearest to he: wink, thou, mya, cybele, nkrumah, tuesday, cloak, masculinity,
# Nearest to in: ect, narrated, donegal, dowland, rak, creation, rabat, regrettable,
# Nearest to to: begins, lace, invents, adrian, molecules, iconoclastic, replicant, effected,
# Nearest to be: free, meteorology, milder, pooh, unicellular, toxic, kaos, effectively,
# Nearest to this: positions, geometric, among, aq, yvonne, isolates, ftc, maximilien,
# Nearest to these: bizarre, nephites, instrumentation, manifestations, politely, extrasolar, wellcome, ceded,
# Nearest to of: gifts, crucifixion, batters, vegan, dispersive, unite, ue, lender,
# Nearest to however: jmp, dvi, classicist, fruitless, switzer, montesquieu, specialties, sported,
# Nearest to there: michelin, xbox, miriam, sim, clarinetist, duddy, microstate, laughs,
# Nearest to zero: castrated, painting, okeh, sensations, ixian, cherokee, duomo, topmost,
# Nearest to only: heavier, ploy, suarez, cancelling, reforestation, sneak, cy, shark,
# Nearest to were: spell, anhalt, gypsum, variadic, robots, invaders, versatile, bloodless,
# Nearest to so: warranties, istria, walla, nabonidus, dur, halifax, fats, placebo,
# Nearest to the: ke, frg, lata, granger, accents, flashy, quakers, guzman,
# Nearest to and: ceiling, cloak, parsing, oxide, kov, speyer, dtv, perfume,
# Nearest to has: records, vacation, sheepdog, pronoun, largest, unitary, disgusted, gimp,
# Average loss at step 2000: 4.370838
# Average loss at step 4000: 3.864385
# Average loss at step 6000: 3.789954
# Average loss at step 8000: 3.686519
# Average loss at step 10000: 3.617280
# Nearest to he: it, they, she, wink, who, utf, there, that,
# Nearest to in: on, of, from, through, with, and, at, after,
# Nearest to to: would, not, interchange, lollards, invents, replicant, telegraph, formats,
# Nearest to be: have, invoking, polyidus, was, been, aucklanders, straightening, legitimate,
# Nearest to this: which, the, it, geometric, that, relating, a, isolates,
# Nearest to these: many, bizarre, proteins, numerous, nephites, generator, texts, such,
# Nearest to of: in, antibiotic, same, for, barn, groening, lei, while,
# Nearest to however: moldovan, dvi, jmp, that, crashing, disabling, unfavorable, orville,
# Nearest to there: it, they, xbox, often, bloodless, he, still, nonviolence,
# Nearest to zero: nine, seven, five, eight, four, six, three, two,
# Nearest to only: heavier, reforestation, cancelling, suarez, gangsta, objectors, birthrate, worrying,
# Nearest to were: are, was, have, spell, interlisp, dirt, keystrokes, davison,
# Nearest to so: warranties, cannot, dur, atheists, psoe, play, years, manet,
# Nearest to the: this, his, a, its, their, an, evolving, megabytes,
# Nearest to and: or, who, in, american, grotto, capacitor, outlawed, garde,
# Nearest to has: had, is, have, was, liberian, exemplar, tyrrhenian, vacation,
# Average loss at step 12000: 3.604891
# Average loss at step 14000: 3.574195
# Average loss at step 16000: 3.410455
# Average loss at step 18000: 3.452250
# Average loss at step 20000: 3.541953
# Nearest to he: it, they, she, who, there, wink, later, queene,
# Nearest to in: at, on, from, during, around, for, with, and,
# Nearest to to: would, invents, may, can, not, griffith, will, should,
# Nearest to be: been, have, were, was, is, invoking, hormonal, by,
# Nearest to this: it, which, the, geometric, levitation, that, another, incensed,
# Nearest to these: many, some, all, such, bizarre, which, nephites, numerous,
# Nearest to of: for, in, and, following, iupac, same, original, subjunctive,
# Nearest to however: but, that, moldovan, sunnis, since, jmp, classicist, dvi,
# Nearest to there: it, they, he, which, often, still, xbox, we,
# Nearest to zero: seven, five, six, four, eight, three, nine, two,
# Nearest to only: heavier, jordi, she, yet, objectors, threatened, menander, understood,
# Nearest to were: are, was, had, have, be, is, by, been,
# Nearest to so: manet, warranties, psoe, cannot, atheists, vall, dur, cabinet,
# Nearest to the: their, its, his, this, any, a, picnic, howland,
# Nearest to and: or, which, but, in, for, of, sarmatian, axles,
# Nearest to has: had, have, is, was, exemplar, having, realtime, stupa,
# Average loss at step 22000: 3.509202
# Average loss at step 24000: 3.490113
# Average loss at step 26000: 3.484797
# Average loss at step 28000: 3.476897
# Average loss at step 30000: 3.508538
# Nearest to he: it, she, they, who, there, wink, never, later,
# Nearest to in: during, at, on, of, throughout, from, under, between,
# Nearest to to: would, invents, can, will, interchange, volkov, moira, convalescence,
# Nearest to be: been, have, is, were, was, become, are, supplying,
# Nearest to this: which, it, that, exhibit, there, geometric, what, the,
# Nearest to these: some, many, such, their, all, which, they, those,
# Nearest to of: in, abstracts, rainer, from, groening, pharmacies, subjunctive, nuggets,
# Nearest to however: but, that, though, where, unelected, since, necks, although,
# Nearest to there: they, it, he, still, often, we, dismiss, this,
# Nearest to zero: five, eight, four, seven, six, nine, three, two,
# Nearest to only: yet, jordi, she, heavier, mosander, understood, birthrate, still,
# Nearest to were: are, was, have, had, been, be, is, by,
# Nearest to so: manet, petite, sometimes, atheists, cannot, psoe, warranties, sciences,
# Nearest to the: their, its, his, some, her, many, conflagration, a,
# Nearest to and: or, but, who, in, ignites, intersections, ackermann, from,
# Nearest to has: had, have, was, is, having, exemplar, molasses, meyer,
# Average loss at step 32000: 3.504292
# Average loss at step 34000: 3.497283
# Average loss at step 36000: 3.454399
# Average loss at step 38000: 3.301925
# Average loss at step 40000: 3.427520
# Nearest to he: it, she, they, there, who, i, subsequently, wink,
# Nearest to in: during, on, from, at, of, with, for, necessitating,
# Nearest to to: lollards, invents, restated, will, absinthium, unicycle, t, eixample,
# Nearest to be: have, been, are, was, is, being, were, straightening,
# Nearest to this: which, it, that, the, another, some, incensed, entailed,
# Nearest to these: many, some, such, both, those, several, their, they,
# Nearest to of: inspires, groening, in, lei, skates, nonzero, mutate, ibizan,
# Nearest to however: but, that, though, where, although, which, necks, unelected,
# Nearest to there: it, they, he, still, often, now, she, which,
# Nearest to zero: seven, five, nine, eight, six, four, three, u,
# Nearest to only: heavier, reforestation, yet, scrupulous, griffey, jordi, methodists, she,
# Nearest to were: are, have, was, had, being, those, be, these,
# Nearest to so: manet, sciences, ebooks, mashal, sometimes, too, rainbows, petite,
# Nearest to the: their, his, any, this, each, some, a, its,
# Nearest to and: or, but, capitoline, without, while, where, unsurprising, brisk,
# Nearest to has: had, have, is, was, exemplar, having, keynote, meyer,
# Average loss at step 42000: 3.439332
# Average loss at step 44000: 3.453938
# Average loss at step 46000: 3.447905
# Average loss at step 48000: 3.357632
# Average loss at step 50000: 3.382897
# Nearest to he: she, it, they, there, who, wink, initially, this,
# Nearest to in: during, of, within, throughout, from, since, on, fumes,
# Nearest to to: may, would, invents, griffith, can, tapered, will, could,
# Nearest to be: have, was, were, been, is, being, become, straightening,
# Nearest to this: which, it, the, he, that, some, beazley, neither,
# Nearest to these: many, some, both, such, several, those, various, which,
# Nearest to of: in, and, including, inspires, skates, subjunctive, genes, deduction,
# Nearest to however: but, though, although, that, where, while, when, unelected,
# Nearest to there: it, they, he, still, now, she, who, we,
# Nearest to zero: five, seven, eight, six, nine, four, three, two,
# Nearest to only: yet, griffey, reforestation, scrupulous, cuauht, lingus, best, still,
# Nearest to were: are, was, have, had, be, those, trousers, been,
# Nearest to so: manet, sometimes, petite, too, sciences, ebooks, she, gehrig,
# Nearest to the: its, their, this, a, his, some, any, bukem,
# Nearest to and: or, but, of, including, while, unsurprising, however, siegel,
# Nearest to has: had, have, is, was, ursinus, since, having, maimed,
# Average loss at step 52000: 3.435207
# Average loss at step 54000: 3.431080
# Average loss at step 56000: 3.436918
# Average loss at step 58000: 3.398922
# Average loss at step 60000: 3.391157
# Nearest to he: she, it, they, there, wink, who, we, later,
# Nearest to in: during, within, of, throughout, since, on, punishes, at,
# Nearest to to: would, invents, may, will, griffith, for, interchange, shiny,
# Nearest to be: been, are, being, have, become, produce, hormonal, polanski,
# Nearest to this: which, it, that, some, there, the, however, what,
# Nearest to these: many, some, those, several, both, such, all, which,
# Nearest to of: in, for, civilis, same, including, groening, pharmacies, or,
# Nearest to however: but, although, though, that, which, since, when, this,
# Nearest to there: it, they, we, he, now, still, she, this,
# Nearest to zero: five, seven, four, eight, six, nine, three, two,
# Nearest to only: yet, scrupulous, lingus, griffey, still, cuauht, ever, reforestation,
# Nearest to were: are, was, although, have, had, been, those, trousers,
# Nearest to so: sometimes, manet, agree, sciences, if, too, absalon, petite,
# Nearest to the: their, its, a, each, this, some, any, firewire,
# Nearest to and: or, but, including, than, mathews, methodist, however, minded,
# Nearest to has: had, have, is, was, having, ursinus, molasses, strengthens,
# Average loss at step 62000: 3.241448
# Average loss at step 64000: 3.254504
# Average loss at step 66000: 3.405109
# Average loss at step 68000: 3.392556
# Average loss at step 70000: 3.357044
# Nearest to he: she, it, they, there, we, wink, later, who,
# Nearest to in: within, during, on, throughout, at, obituaries, until, for,
# Nearest to to: would, will, volkov, can, invents, may, must, always,
# Nearest to be: been, is, were, being, have, become, are, was,
# Nearest to this: which, it, another, the, that, some, there, each,
# Nearest to these: such, many, some, several, those, their, which, various,
# Nearest to of: including, skates, inspires, in, for, civilis, include, greene,
# Nearest to however: but, although, though, where, that, when, while, time,
# Nearest to there: they, it, we, still, he, she, now, usually,
# Nearest to zero: five, eight, six, four, seven, nine, three, two,
# Nearest to only: ever, reforestation, best, yet, either, cosmonaut, scrupulous, still,
# Nearest to were: are, was, have, had, be, although, been, those,
# Nearest to so: sometimes, too, sciences, manet, absalon, gehrig, ebooks, hephaestion,
# Nearest to the: its, their, a, each, any, this, some, his,
# Nearest to and: or, but, while, including, unsurprising, ammonium, intersections, moncada,
# Nearest to has: had, have, is, was, since, having, maimed, ursinus,
# Average loss at step 72000: 3.374899
# Average loss at step 74000: 3.348148
# Average loss at step 76000: 3.314493
# Average loss at step 78000: 3.350731
# Average loss at step 80000: 3.373344
# Nearest to he: she, it, they, there, who, we, wink, later,
# Nearest to in: within, during, on, until, throughout, under, around, between,
# Nearest to to: would, invents, will, griffith, volkov, interchange, restated, moira,
# Nearest to be: been, have, being, is, become, were, was, referring,
# Nearest to this: it, which, the, stencils, another, fiddler, itself, that,
# Nearest to these: many, those, several, some, such, both, various, multiple,
# Nearest to of: including, inspires, lei, in, under, groening, pharmacies, ibizan,
# Nearest to however: although, but, though, that, where, especially, while, when,
# Nearest to there: it, they, he, still, she, we, usually, now,
# Nearest to zero: five, seven, six, eight, four, three, nine, u,
# Nearest to only: ever, best, reforestation, actually, griffey, cosmonaut, always, hinted,
# Nearest to were: are, was, had, have, although, be, being, those,
# Nearest to so: too, if, sometimes, when, absalon, agree, gehrig, financially,
# Nearest to the: its, their, this, a, howland, his, surrey, bogdanovich,
# Nearest to and: or, while, but, including, isoleucine, krause, veneer, although,
# Nearest to has: had, have, is, was, having, since, exemplar, ursinus,
# Average loss at step 82000: 3.403492
# Average loss at step 84000: 3.411490
# Average loss at step 86000: 3.391088
# Average loss at step 88000: 3.348793
# Average loss at step 90000: 3.365334
# Nearest to he: she, it, they, there, who, later, initially, we,
# Nearest to in: within, during, under, between, throughout, of, until, with,
# Nearest to to: invents, towards, would, will, convalescence, tapered, exasperation, should,
# Nearest to be: been, was, is, have, become, being, hormonal, supplying,
# Nearest to this: it, which, another, the, some, herders, pragmatic, heroics,
# Nearest to these: several, many, some, those, such, both, multiple, are,
# Nearest to of: including, for, inspires, in, blockbusters, skates, lei, subjunctive,
# Nearest to however: but, although, though, that, where, since, especially, argentinian,
# Nearest to there: they, it, still, we, she, he, now, sometimes,
# Nearest to zero: seven, five, eight, six, nine, four, three, u,
# Nearest to only: no, actually, ever, reforestation, best, generally, either, sinuous,
# Nearest to were: are, had, was, have, although, while, trousers, being,
# Nearest to so: if, too, thus, hephaestion, rainbows, nor, before, financially,
# Nearest to the: its, any, their, his, a, this, syed, attributing,
# Nearest to and: or, but, while, unsurprising, including, however, dell, faculties,
# Nearest to has: had, have, is, having, since, was, contains, turntables,
# Average loss at step 92000: 3.400785
# Average loss at step 94000: 3.253615
# Average loss at step 96000: 3.361066
# Average loss at step 98000: 3.243930
# Average loss at step 100000: 3.357187
# Nearest to he: she, it, they, there, who, we, never, wink,
# Nearest to in: during, within, until, throughout, on, from, of, at,
# Nearest to to: will, would, could, must, should, can, cannot, invents,
# Nearest to be: been, become, are, being, is, have, were, hormonal,
# Nearest to this: it, which, another, some, he, heroics, itself, the,
# Nearest to these: several, many, some, those, various, which, such, all,
# Nearest to of: balliol, inspires, civilis, in, including, and, pharmacies, original,
# Nearest to however: but, although, though, that, where, especially, and, which,
# Nearest to there: they, it, he, still, we, now, she, often,
# Nearest to zero: five, eight, seven, four, six, nine, three, two,
# Nearest to only: reforestation, actually, no, ever, generally, best, sukkot, griffey,
# Nearest to were: are, was, had, have, these, those, prefer, although,
# Nearest to so: thus, too, sometimes, when, financially, absalon, then, rainbows,
# Nearest to the: their, its, his, a, our, your, troopers, this,
# Nearest to and: or, but, nor, unsurprising, however, like, although, who,
# Nearest to has: had, have, is, was, having, since, contains, saltwater,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch_cbow(batch_size, num_context_left, num_context_right):
  global data_index
  batch = np.ndarray(shape=(batch_size, num_context_left+num_context_right), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = num_context_left + num_context_right + 1 # [ num_context_left target num_context_right ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size): 
    target = num_context_left  # target label at the center of the buffer
    targets_to_avoid = [ target ]
    for j in range(num_context_left + num_context_right):
      context = target
      while context in targets_to_avoid:
        context = random.randint(0, span - 1)
      targets_to_avoid.append(context)
      batch[i,j] = buffer[context]
    labels[i,0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:12]])

for num_context_left, num_context_right in [(1, 1), (2, 1)]:
    data_index = 0
    batch_size = 8
    batch, labels = generate_batch_cbow(batch_size, num_context_left, num_context_right)
    print('\nwith num_context_left = %d and num_context_right = %d:' % (num_context_left, num_context_right))
    for i in range(batch_size):
        print('    batch:', [reverse_dictionary[bi] for bi in batch[i,:].reshape(num_context_left+num_context_right)])
        print('    label:', reverse_dictionary[labels[i,0]])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working']
#
# with num_context_left = 1 and num_context_right = 1:
#     batch: ['anarchism', 'as']
#     label: originated
#     batch: ['originated', 'a']
#     label: as
#     batch: ['term', 'as']
#     label: a
#     batch: ['a', 'of']
#     label: term
#     batch: ['abuse', 'term']
#     label: of
#     batch: ['first', 'of']
#     label: abuse
#     batch: ['abuse', 'used']
#     label: first
#     batch: ['against', 'first']
#     label: used
#
# with num_context_left = 2 and num_context_right = 1:
#     batch: ['a', 'anarchism', 'originated']
#     label: as
#     batch: ['term', 'originated', 'as']
#     label: a
#     batch: ['of', 'as', 'a']
#     label: term
#     batch: ['a', 'abuse', 'term']
#     label: of
#     batch: ['of', 'first', 'term']
#     label: abuse
#     batch: ['of', 'abuse', 'used']
#     label: first
#     batch: ['abuse', 'against', 'first']
#     label: used
#     batch: ['used', 'early', 'first']
#     label: against

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
num_context_left = 1 
num_context_right = 1 
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, num_context_left+num_context_right])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  averaged_embed = tf.reduce_mean(embed, 1)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=averaged_embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_cbow(
      batch_size, num_context_left, num_context_right)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.681148
# Nearest to of: producers, toy, convergence, cryogenic, labels, iain, profanity, valiantly,
# Nearest to at: olaf, deception, tiff, fireballs, consolation, sales, qaddafi, embracing,
# Nearest to system: characters, flocked, preface, indifferent, kowloon, redaction, dewar, aquileia,
# Nearest to and: safed, unchecked, previous, monocots, tosefta, inauguration, clampett, path,
# Nearest to the: refrigeration, engraver, widened, liliales, shia, photoelectric, participates, seigenthaler,
# Nearest to with: celestial, vertical, hayes, albigensians, applet, expressed, limerick, helper,
# Nearest to people: urbino, freeway, fallen, implicit, netbsd, archival, homomorphisms, saber,
# Nearest to no: hawthorne, thee, heater, hf, encounters, crimea, taught, friars,
# Nearest to or: introns, was, qassam, marsilio, compulsive, hornblower, flowed, storehouse,
# Nearest to for: gadamer, drachma, tischendorf, cation, levies, owning, veneer, scroll,
# Nearest to american: baptiste, philippine, hinterlands, decay, akm, quickdraw, popolo, palsy,
# Nearest to who: vidkun, homoerotic, ht, folding, twos, austrians, uighur, generalities,
# Nearest to nine: walter, enthusiasts, alterations, keitel, character, priceless, camilla, linker,
# Nearest to first: autograph, put, filter, format, swann, desmodromic, penfield, treblinka,
# Nearest to war: cbe, eucharistic, conjectural, sira, koruna, parable, manitoba, rolls,
# Nearest to states: manslaughter, heads, dorado, swerve, gne, tupi, eisenhower, idiopathic,
# Average loss at step 2000: 4.038627
# Average loss at step 4000: 3.509731
# Average loss at step 6000: 3.342700
# Average loss at step 8000: 3.191673
# Average loss at step 10000: 3.148122
# Nearest to of: cryogenic, picker, cdna, dual, louie, in, mf, tuscany,
# Nearest to at: on, in, near, trembling, proteases, during, stra, cemented,
# Nearest to system: stratospheric, untouched, indifferent, characters, extremadura, xy, cedilla, hallucinations,
# Nearest to and: or, fluorine, errands, enshrined, rocker, centric, receive, obstinate,
# Nearest to the: its, their, his, this, any, a, mapsto, rulebook,
# Nearest to with: celestial, in, for, burney, darboux, dwelling, by, between,
# Nearest to people: bilabial, homomorphisms, implicit, durango, penchant, tcp, archival, saber,
# Nearest to no: airstrips, encounters, heater, still, warp, commonly, unproductive, often,
# Nearest to or: and, introns, bundeswehr, cipher, spotted, than, bleed, issuance,
# Nearest to for: statuary, marienburg, applescript, drachma, with, owning, cusp, cation,
# Nearest to american: autodesk, fremont, trees, baptiste, papeete, british, nz, budd,
# Nearest to who: he, informed, now, they, twister, illuminism, ht, homoerotic,
# Nearest to nine: eight, six, seven, five, four, zero, three, two,
# Nearest to first: jagiellon, same, swann, format, deceiving, atrophy, philosophical, jurist,
# Nearest to war: cbe, separations, koruna, sira, eucharistic, manitoba, mythologie, mercalli,
# Nearest to states: nations, heads, manslaughter, swerve, furies, local, gne, dorado,
# Average loss at step 12000: 3.170195
# Average loss at step 14000: 3.128296
# Average loss at step 16000: 3.148256
# Average loss at step 18000: 3.104848
# Average loss at step 20000: 2.989318
# Nearest to of: picker, nicht, erroneous, illusion, cryogenic, dual, philby, cdna,
# Nearest to at: during, on, in, near, stra, editing, within, bacchus,
# Nearest to system: untouched, indifferent, hugs, xy, alfred, apulia, flocked, extremadura,
# Nearest to and: or, but, concentrating, errands, fluorine, while, seeming, jsr,
# Nearest to the: a, their, its, any, our, this, his, rulebook,
# Nearest to with: between, celestial, dwelling, darboux, burney, against, vertical, without,
# Nearest to people: bilabial, homomorphisms, freeway, penchant, racks, tcp, closet, triumphantly,
# Nearest to no: airstrips, still, encounters, heater, any, karst, users, warp,
# Nearest to or: and, than, tudor, bundeswehr, bleed, cipher, issuance, disconnected,
# Nearest to for: owning, drachma, marienburg, statuary, applescript, coleman, tischendorf, mexicans,
# Nearest to american: autodesk, british, mercalli, philippine, nz, trees, philia, australian,
# Nearest to who: he, she, ramen, twister, informed, vdc, now, they,
# Nearest to nine: eight, seven, six, five, zero, four, three, one,
# Nearest to first: next, jagiellon, second, swann, apostasy, deceiving, philosophical, same,
# Nearest to war: cbe, sira, rolls, eucharistic, extracting, koruna, separations, skiers,
# Nearest to states: nations, heads, swerve, manslaughter, furies, graceful, local, countries,
# Average loss at step 22000: 3.049209
# Average loss at step 24000: 3.025891
# Average loss at step 26000: 2.989531
# Average loss at step 28000: 3.017088
# Average loss at step 30000: 2.990805
# Nearest to of: including, dual, picker, illusion, cryogenic, superpowered, mondo, nakano,
# Nearest to at: during, near, on, in, dwt, bacchus, sporty, sprinkled,
# Nearest to system: systems, hugs, indifferent, redirected, untouched, xy, bolt, allegiance,
# Nearest to and: or, but, fluorine, concentrating, corrections, springtime, including, randell,
# Nearest to the: their, its, this, any, our, a, onesimus, your,
# Nearest to with: between, vertical, against, amending, burney, celestial, peaceful, glaciations,
# Nearest to people: homomorphisms, penchant, triumphantly, racks, bilabial, fleet, tcp, freeway,
# Nearest to no: any, hairy, karst, nicene, erosion, ribbentrop, warp, heater,
# Nearest to or: and, than, heinlein, bundeswehr, cipher, depicting, roasted, introns,
# Nearest to for: owning, applescript, drachma, specially, turf, mexicans, marienburg, greatest,
# Nearest to american: british, mercalli, australian, autodesk, webber, german, gordon, philippine,
# Nearest to who: he, which, bypasses, she, leblanc, they, tricity, twister,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to first: last, next, second, jagiellon, jurist, same, third, deceiving,
# Nearest to war: cbe, rolls, sira, eucharistic, extracting, koruna, skiers, separations,
# Nearest to states: nations, kingdom, countries, heads, manslaughter, swerve, graceful, furies,
# Average loss at step 32000: 2.841081
# Average loss at step 34000: 2.946711
# Average loss at step 36000: 2.940315
# Average loss at step 38000: 2.941354
# Average loss at step 40000: 2.921712
# Nearest to of: including, cryogenic, actual, illusion, original, entire, oeuvres, cdna,
# Nearest to at: near, during, in, bacchus, dap, degenerative, counterattacks, zbigniew,
# Nearest to system: systems, hugs, indifferent, utilizing, redirected, hunters, objectivist, bolt,
# Nearest to and: or, but, heiner, while, fluorine, pence, errands, deist,
# Nearest to the: their, its, your, mercilessly, onesimus, any, his, mapsto,
# Nearest to with: between, burney, glaciations, amending, darboux, vertical, lodged, celestial,
# Nearest to people: men, women, homomorphisms, freeway, penchant, fleet, folk, murphy,
# Nearest to no: any, nicene, heater, karst, airstrips, hairy, pomorza, genetic,
# Nearest to or: and, than, issuance, qassam, depicting, roasted, electronegative, cipher,
# Nearest to for: applescript, turf, owning, suffixed, mexicans, drachma, specially, when,
# Nearest to american: british, australian, mercalli, webber, french, autodesk, gordon, western,
# Nearest to who: he, bypasses, ramen, she, leblanc, typically, they, which,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to first: last, second, next, third, jagiellon, best, jurist, final,
# Nearest to war: cbe, rolls, sira, koruna, eucharistic, extracting, depriving, skiers,
# Nearest to states: nations, kingdom, countries, manslaughter, heads, swerve, graceful, passos,
# Average loss at step 42000: 2.939483
# Average loss at step 44000: 2.945304
# Average loss at step 46000: 2.903208
# Average loss at step 48000: 2.870858
# Average loss at step 50000: 2.842564
# Nearest to of: including, picker, in, elvish, during, erroneous, lip, specifics,
# Nearest to at: in, near, during, sporty, selkirk, bacchus, on, endnotes,
# Nearest to system: systems, hugs, process, utilizing, objectivist, redirected, neologism, xy,
# Nearest to and: or, but, fluorine, errands, while, concentrating, telecom, bacharach,
# Nearest to the: its, rulebook, a, their, your, any, onesimus, his,
# Nearest to with: between, burney, glaciations, against, amending, vertical, dwelling, peaceful,
# Nearest to people: men, malfunction, women, homomorphisms, penchant, petrel, someone, folk,
# Nearest to no: any, erosion, karst, hairy, nicene, unproductive, pomorza, tcl,
# Nearest to or: and, issuance, than, tudor, schengen, cipher, powiat, spore,
# Nearest to for: turf, applescript, owning, wheelbase, suffixed, specially, when, marienburg,
# Nearest to american: british, french, gordon, australian, budd, fremont, mercalli, german,
# Nearest to who: he, bypasses, leblanc, typically, twister, she, probably, indistinguishable,
# Nearest to nine: eight, seven, six, four, five, zero, three, two,
# Nearest to first: last, second, next, third, jagiellon, final, best, wels,
# Nearest to war: cbe, rolls, sira, extracting, eucharistic, koruna, title, hearing,
# Nearest to states: nations, kingdom, countries, graceful, manslaughter, union, heads, passos,
# Average loss at step 52000: 2.885399
# Average loss at step 54000: 2.861811
# Average loss at step 56000: 2.854719
# Average loss at step 58000: 2.762917
# Average loss at step 60000: 2.825171
# Nearest to of: picker, including, elvish, disturbs, include, cryogenic, consider, unconquered,
# Nearest to at: during, near, in, on, sporty, bacchus, dap, endnotes,
# Nearest to system: systems, process, devices, hunters, neologism, redirected, crisis, utilizing,
# Nearest to and: or, but, concentrating, while, fluorine, dap, corrections, gaines,
# Nearest to the: our, their, its, your, his, rulebook, habitability, onesimus,
# Nearest to with: between, glaciations, vertical, peaceful, amending, burney, peep, darboux,
# Nearest to people: men, women, children, malfunction, players, folk, someone, fleet,
# Nearest to no: any, little, karst, tcl, erosion, only, hairy, nicene,
# Nearest to or: and, than, vx, bundeswehr, tudor, deoxygenated, spore, electronegative,
# Nearest to for: turf, applescript, wheelbase, barbuda, diels, owning, suffixed, catania,
# Nearest to american: british, australian, english, gordon, german, mercalli, french, irish,
# Nearest to who: he, she, bypasses, probably, leblanc, vdc, typically, often,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to first: last, second, next, third, final, jagiellon, best, gymnosperms,
# Nearest to war: cbe, rolls, koruna, attribution, eucharistic, sira, title, mercalli,
# Nearest to states: nations, kingdom, countries, graceful, state, manslaughter, union, researchers,
# Average loss at step 62000: 2.835344
# Average loss at step 64000: 2.775632
# Average loss at step 66000: 2.771021
# Average loss at step 68000: 2.718386
# Average loss at step 70000: 2.775462
# Nearest to of: in, including, elvish, dynamo, grands, picker, cryogenic, valiantly,
# Nearest to at: during, near, in, decins, bacchus, sporty, on, dap,
# Nearest to system: systems, process, devices, afforded, crisis, neologism, shearer, hunters,
# Nearest to and: but, or, while, fluorine, although, errands, heiner, seeming,
# Nearest to the: its, their, a, his, rulebook, onesimus, any, our,
# Nearest to with: between, burney, peaceful, darboux, vertical, against, rif, by,
# Nearest to people: men, women, players, children, man, someone, individuals, words,
# Nearest to no: any, tcl, stoke, preserves, erosion, heater, monastics, hairy,
# Nearest to or: and, than, tudor, integrase, introns, issuance, spore, choke,
# Nearest to for: applescript, owning, wheelbase, turf, catania, suffixed, mahdi, mexicans,
# Nearest to american: british, australian, gordon, english, german, fremont, french, mercalli,
# Nearest to who: he, she, leblanc, bypasses, which, typically, vdc, probably,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to first: last, second, third, next, jagiellon, best, fourth, gymnosperms,
# Nearest to war: cbe, rolls, eucharistic, sira, koruna, extracting, attribution, mercalli,
# Nearest to states: nations, kingdom, state, countries, manslaughter, union, graceful, passos,
# Average loss at step 72000: 2.804145
# Average loss at step 74000: 2.657671
# Average loss at step 76000: 2.801891
# Average loss at step 78000: 2.822626
# Average loss at step 80000: 2.787735
# Nearest to of: including, in, dynamo, elvish, picker, grands, gotta, actual,
# Nearest to at: near, during, in, sporty, on, dap, bacchus, under,
# Nearest to system: systems, process, devices, afforded, neologism, redirected, shearer, hunters,
# Nearest to and: or, but, including, fluorine, cyp, deist, bedi, although,
# Nearest to the: rulebook, its, their, mercilessly, onesimus, habitability, our, your,
# Nearest to with: between, burney, vertical, glaciations, including, amending, against, when,
# Nearest to people: men, man, women, children, players, someone, malfunction, words,
# Nearest to no: any, tcl, erosion, little, hairy, monastics, nontrivial, only,
# Nearest to or: and, than, though, introns, et, und, spore, apologist,
# Nearest to for: turf, after, applescript, despite, when, owning, mexicans, mahdi,
# Nearest to american: british, australian, italian, german, french, english, mercalli, irish,
# Nearest to who: he, bypasses, she, leblanc, probably, which, typically, vdc,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to first: last, second, next, third, jagiellon, best, final, fourth,
# Nearest to war: cbe, rolls, sira, eucharistic, attribution, mercalli, extracting, champion,
# Nearest to states: nations, kingdom, countries, state, manslaughter, union, passos, graceful,
# Average loss at step 82000: 2.676184
# Average loss at step 84000: 2.772132
# Average loss at step 86000: 2.740252
# Average loss at step 88000: 2.758163
# Average loss at step 90000: 2.743117
# Nearest to of: cryogenic, dynamo, elvish, regarding, actual, erroneous, orig, superpowered,
# Nearest to at: near, during, in, sporty, decins, dap, on, formerly,
# Nearest to system: systems, process, afforded, devices, crisis, diet, situation, neologism,
# Nearest to and: or, but, fluorine, including, gaines, ethnicities, heiner, jsr,
# Nearest to the: its, rulebook, their, our, his, your, onesimus, habitability,
# Nearest to with: between, burney, including, vertical, trudeau, glaciations, darboux, amending,
# Nearest to people: men, women, man, players, children, individuals, words, malfunction,
# Nearest to no: any, little, tcl, erosion, monastics, bius, maduro, complicated,
# Nearest to or: and, than, posner, vx, bolo, andrey, et, wieman,
# Nearest to for: turf, mexicans, applescript, despite, catania, owning, after, uncharacteristically,
# Nearest to american: british, australian, italian, french, irish, german, english, mercalli,
# Nearest to who: he, typically, bypasses, which, leblanc, often, she, probably,
# Nearest to nine: eight, seven, six, four, five, zero, three, two,
# Nearest to first: last, second, next, third, jagiellon, best, gymnosperms, fourth,
# Nearest to war: rolls, cbe, wars, sira, attribution, champion, mercalli, skiers,
# Nearest to states: nations, kingdom, countries, state, manslaughter, passos, graceful, union,
# Average loss at step 92000: 2.687085
# Average loss at step 94000: 2.728080
# Average loss at step 96000: 2.708195
# Average loss at step 98000: 2.383176
# Average loss at step 100000: 2.423662
# Nearest to of: elvish, dynamo, regarding, in, grands, magnetometer, gotta, cryogenic,
# Nearest to at: near, in, during, decins, dap, sporty, on, after,
# Nearest to system: systems, process, afforded, devices, crisis, diet, tyr, objectivist,
# Nearest to and: or, but, fluorine, bacharach, joyce, heiner, fleeting, dap,
# Nearest to the: his, their, rulebook, your, its, our, onesimus, habitability,
# Nearest to with: between, burney, darboux, vertical, glaciations, tribulation, trudeau, including,
# Nearest to people: men, women, man, children, person, americans, individuals, players,
# Nearest to no: any, little, tcl, monastics, maduro, nontrivial, erosion, departmental,
# Nearest to or: and, than, et, qassam, posner, electronegative, integrase, bolo,
# Nearest to for: turf, after, despite, applescript, mexicans, sphincter, wheelbase, when,
# Nearest to american: british, english, australian, canadian, french, norwegian, german, gordon,
# Nearest to who: which, bypasses, he, often, typically, probably, leblanc, she,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to first: last, second, next, third, jagiellon, best, fourth, gymnosperms,
# Nearest to war: wars, cbe, champion, rolls, mercalli, sira, koruna, deficiency,
# Nearest to states: nations, kingdom, state, countries, graceful, union, researchers, passos,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
